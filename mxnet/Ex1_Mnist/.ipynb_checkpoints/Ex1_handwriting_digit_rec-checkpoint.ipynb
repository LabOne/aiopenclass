# %% [markdown]
# ## Exercise 1: Handwritten Digit Recognition
#
# In this tutorial we will go through the basic use case of MXNet and also touch on some advanced usages. This example is based on the MNIST dataset, which contains 70,000 images of hand written characters with 28-by-28 pixel size.
#
# This tutorial covers the following topics:
# - network definition.
# - Variable naming.
# - Basic data loading and training with feed-forward deep neural networks.
# - Monitoring intermediate outputs for debuging.
# - Custom training loop for advanced models.

# %%
# %matplotlib inline
import mxnet as mx
import numpy as np
import cv2
import matplotlib.pyplot as plt
import logging

# %% [markdown]
# ### Network Definition
# Now we can start constructing our basic network, multilayer percepton:

# %%
#Create a multilayer pecepton   
# Create a place holder variable for the input data
data = mx.sym.Variable('data')
# Flatten the data from 4-D shape (batch_size, num_channel, width, height) 
# into 2-D (batch_size, num_channel*width*height)
data = mx.sym.Flatten(data=data)

# The first fully-connected layer
fc1  = mx.sym.FullyConnected(data=data, name='fc1', num_hidden=128)
# Apply relu to the output of the first fully-connnected layer
act1 = mx.sym.Activation(data=fc1, name='relu1', act_type="relu")

# The second fully-connected layer and the according activation function
fc2  = mx.sym.FullyConnected(data=act1, name='fc2', num_hidden = 64)
act2 = mx.sym.Activation(data=fc2, name='relu2', act_type="relu")

# The thrid fully-connected layer, note that the hidden size should be 10, 
#    the number of unique digits
fc3  = mx.sym.FullyConnected(data=act2, name='fc3', num_hidden=10)
# The softmax and loss layer
mlp  = mx.sym.SoftmaxOutput(data=fc3, name='softmax')

# %% [markdown]
# We can visualize the network we just defined with MXNet's visualization module:

# %%
# We visualize the network structure with output size (the batch_size is ignored.)
shape = {"data" : (100, 1, 28, 28)}
mx.viz.plot_network(symbol=mlp, shape=shape)

# %% [markdown]
# ### Variable Naming
#
# MXNet requires variable names to follow certain conventions:
# - All input arrays have a name. This includes inputs (data & label) and model parameters (weight, bias, etc).
# - Arrays can be renamed by creating named variable. Otherwise, a default name is given as 'SymbolName_ArrayName'. For example, FullyConnected symbol fc1's weight array is named as 'fc1_weight'.
# - Although you can also rename weight arrays with variables, weight array's name should always end with '_weight' and bias array '_bias'. MXNet relies on the suffixes of array names to correctly initialize & update them.
#
# Call list_arguments method on a symbol to get the names of all its inputs:

# %%
mlp.list_arguments()
# Out:
# ['data',
#  'fc1_weight',
#  'fc1_bias',
#  'fc2_weight',
#  'fc2_bias',
#  'fc3_weight',
#  'fc3_bias',
#  'softmax_label']

# %% [markdown]
# ### Data Loading
#
# We fetch and load the MNIST dataset including training and test dataset. We also visualize a few examples to get an idea of what the dataset looks like.

# %%
# Download and load the dataset 
import numpy as np
import os
import urllib
import gzip
import struct
def download_data(url, force_download=True): 
    fname = url.split("/")[-1]
    if force_download or not os.path.exists(fname):
        urllib.urlretrieve(url, fname)
    return fname

def read_data(label_url, image_url):
    with gzip.open(download_data(label_url)) as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        label = np.fromstring(flbl.read(), dtype=np.int8)
    with gzip.open(download_data(image_url), 'rb') as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        image = np.fromstring(fimg.read(), dtype=np.uint8).reshape(len(label), rows, cols)
    return (label, image)

path='http://yann.lecun.com/exdb/mnist/'
(train_lbl, train_img) = read_data(
    path+'train-labels-idx1-ubyte.gz', path+'train-images-idx3-ubyte.gz')
(val_lbl, val_img) = read_data(
    path+'t10k-labels-idx1-ubyte.gz', path+'t10k-images-idx3-ubyte.gz')

# %%
# Show some samples of the pictures 
# %matplotlib inline
import matplotlib.pyplot as plt
for i in range(12):
    plt.subplot(1,12,i+1)
    plt.imshow(train_img[i], cmap='Greys_r')
    plt.axis('off')
plt.show()
print('label: %s' % (train_lbl[0:12],))
# Out:
# label: [5 0 4 1 9 2 1 3 1 4 3 5]

# %% [markdown]
# Now we can create data iterators from our MNIST data. A data iterator returns a batch of data examples each time for the network to process. MXNet provide a suite of basic DataIters for parsing different data format. Here we use NDArrayIter, which wraps around a numpy array and each time slice a chunk from it along the first dimension.

# %%
#Convert the data into the format used for MxNet's NN 
import mxnet as mx

def to4d(img):
    return img.reshape(img.shape[0], 1, 28, 28).astype(np.float32)/255

batch_size = 100
train_iter = mx.io.NDArrayIter(to4d(train_img), train_lbl, batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(to4d(val_img), val_lbl, batch_size)

# %% [markdown]
# ### Training
#
# With the network and data source defined, we can finally start to train our model. We do this with MXNet's convenience wrapper for feed forward neural networks (it can also be made to handle RNNs with explicit unrolling).

# %%
# Train and validate the model with the training sample 
import logging
logging.getLogger().setLevel(logging.DEBUG)

model = mx.model.FeedForward(
    ctx = mx.cpu(0),      # Run on CPU 0; changed into gpu if gpu used 
    symbol = mlp,         # Use the network we just defined
    num_epoch = 10,       # Train for 10 epochs
    learning_rate = 0.1,  # Learning rate
    momentum = 0.9,       # Momentum for SGD with momentum
    wd = 0.00001)         # Weight decay for regularization
model.fit(
    X=train_iter,  # Training data set
    eval_data=val_iter,  # Testing data set. MXNet computes scores on test set every epoch
    batch_end_callback = mx.callback.Speedometer(batch_size, 200))  # Logging module to print out progress
# Out:
# /home/lpola/.virtualenvs/cv/lib/python2.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#   # This is added back by InteractiveShellApp.init_path()
# /home/lpola/mxnet/python/mxnet/model.py:516: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 8939.78 samples/sec	Train-accuracy=0.385750
# INFO:root:Epoch[0] Batch [400]	Speed: 11144.15 samples/sec	Train-accuracy=0.898750
# INFO:root:Epoch[0] Batch [600]	Speed: 9294.85 samples/sec	Train-accuracy=0.939500
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=6.239
# INFO:root:Epoch[0] Validation-accuracy=0.946600
# INFO:root:Epoch[1] Batch [200]	Speed: 7053.80 samples/sec	Train-accuracy=0.952050
# INFO:root:Epoch[1] Batch [400]	Speed: 9479.80 samples/sec	Train-accuracy=0.960250
# INFO:root:Epoch[1] Batch [600]	Speed: 10893.46 samples/sec	Train-accuracy=0.964650
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=6.814
# INFO:root:Epoch[1] Validation-accuracy=0.960500
# INFO:root:Epoch[2] Batch [200]	Speed: 12450.73 samples/sec	Train-accuracy=0.967750
# INFO:root:Epoch[2] Batch [400]	Speed: 12693.11 samples/sec	Train-accuracy=0.972750
# INFO:root:Epoch[2] Batch [600]	Speed: 11382.79 samples/sec	Train-accuracy=0.973650
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=4.981
# INFO:root:Epoch[2] Validation-accuracy=0.966000
# INFO:root:Epoch[3] Batch [200]	Speed: 12352.68 samples/sec	Train-accuracy=0.976250
# INFO:root:Epoch[3] Batch [400]	Speed: 11288.27 samples/sec	Train-accuracy=0.978100
# INFO:root:Epoch[3] Batch [600]	Speed: 12432.01 samples/sec	Train-accuracy=0.979450
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=5.046
# INFO:root:Epoch[3] Validation-accuracy=0.969900
# INFO:root:Epoch[4] Batch [200]	Speed: 12424.13 samples/sec	Train-accuracy=0.981300
# INFO:root:Epoch[4] Batch [400]	Speed: 10383.22 samples/sec	Train-accuracy=0.980800
# INFO:root:Epoch[4] Batch [600]	Speed: 10877.41 samples/sec	Train-accuracy=0.981900
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=5.407
# INFO:root:Epoch[4] Validation-accuracy=0.970100
# INFO:root:Epoch[5] Batch [200]	Speed: 11170.57 samples/sec	Train-accuracy=0.984750
# INFO:root:Epoch[5] Batch [400]	Speed: 11926.96 samples/sec	Train-accuracy=0.984100
# INFO:root:Epoch[5] Batch [600]	Speed: 11902.98 samples/sec	Train-accuracy=0.984500
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=5.187
# INFO:root:Epoch[5] Validation-accuracy=0.976900
# INFO:root:Epoch[6] Batch [200]	Speed: 11381.42 samples/sec	Train-accuracy=0.986000
# INFO:root:Epoch[6] Batch [400]	Speed: 11509.44 samples/sec	Train-accuracy=0.988300
# INFO:root:Epoch[6] Batch [600]	Speed: 10794.34 samples/sec	Train-accuracy=0.986500
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=5.388
# INFO:root:Epoch[6] Validation-accuracy=0.977100
# INFO:root:Epoch[7] Batch [200]	Speed: 12058.73 samples/sec	Train-accuracy=0.987150
# INFO:root:Epoch[7] Batch [400]	Speed: 11926.19 samples/sec	Train-accuracy=0.988300
# INFO:root:Epoch[7] Batch [600]	Speed: 12370.16 samples/sec	Train-accuracy=0.986650
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=4.996
# INFO:root:Epoch[7] Validation-accuracy=0.976200
# INFO:root:Epoch[8] Batch [200]	Speed: 12179.00 samples/sec	Train-accuracy=0.988150
# INFO:root:Epoch[8] Batch [400]	Speed: 11969.97 samples/sec	Train-accuracy=0.988950
# INFO:root:Epoch[8] Batch [600]	Speed: 12511.60 samples/sec	Train-accuracy=0.989300
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=4.953
# INFO:root:Epoch[8] Validation-accuracy=0.975500
# INFO:root:Epoch[9] Batch [200]	Speed: 12399.59 samples/sec	Train-accuracy=0.988000
# INFO:root:Epoch[9] Batch [400]	Speed: 12204.07 samples/sec	Train-accuracy=0.989500
# INFO:root:Epoch[9] Batch [600]	Speed: 12009.82 samples/sec	Train-accuracy=0.990700
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=4.958
# INFO:root:Epoch[9] Validation-accuracy=0.973000

# %% [markdown]
# ### Evaluation
#
# After the model is trained, we can evaluate it on a held out test set.
# First, lets classity a sample image:

# %%
# Show one result of the validated dataset 
import random 
index=random.randint(0,len(val_img))
plt.imshow(val_img[index], cmap='Greys_r')
plt.axis('off')
plt.show()
prob = model.predict(val_img[index:(index+1)].astype(np.float32)/255)[0]
assert max(prob) > 0.99, "Low prediction accuracy for id "+str(index)+"; prob:"+str(max(prob))
print 'Classified as %d with probability %f' % (prob.argmax(), max(prob))
# Out:
# Classified as 8 with probability 0.999985

# %% [markdown]
# We can also evaluate the model's accuracy on the entire test set:

# %%
print 'Accuracy:', model.score(val_iter)*100, '%'
# Out:
# Accuracy: 97.3 %

# %% [markdown]
# Now, try if your model recognizes your own hand writing.
# Write a digit from 0 to 9 in the box below. Try to put your digit in the middle of the box.

# %%
# run hand drawing test
from IPython.display import HTML

def classify(img):
    img = img[len('data:image/png;base64,'):].decode('base64')
    img = cv2.imdecode(np.fromstring(img, np.uint8), -1)
    img = cv2.resize(img[:,:,3], (28,28))
    img = img.astype(np.float32).reshape((1, 784))/255.0
    return model.predict(img)[0].argmax()

html = """<style type="text/css">canvas { border: 1px solid black; }</style><div id="board"><canvas id="myCanvas" width="100px" height="100px">Sorry, your browser doesn't support canvas technology.</canvas><p><button id="classify" onclick="classify()">Classify</button><button id="clear" onclick="myClear()">Clear</button>Result: <input type="text" id="result_output" size="5" value=""></p></div>"""
script = """<script type="text/JavaScript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.2/jquery.min.js?ver=1.4.2"></script><script type="text/javascript">function init() {var myCanvas = document.getElementById("myCanvas");var curColor = $('#selectColor option:selected').val();if(myCanvas){var isDown = false;var ctx = myCanvas.getContext("2d");var canvasX, canvasY;ctx.lineWidth = 8;$(myCanvas).mousedown(function(e){isDown = true;ctx.beginPath();var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.moveTo(canvasX, canvasY);}).mousemove(function(e){if(isDown != false) {var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.lineTo(canvasX, canvasY);ctx.strokeStyle = curColor;ctx.stroke();}}).mouseup(function(e){isDown = false;ctx.closePath();});}$('#selectColor').change(function () {curColor = $('#selectColor option:selected').val();});}init();function handle_output(out) {document.getElementById("result_output").value = out.content.data["text/plain"];}function classify() {var kernel = IPython.notebook.kernel;var myCanvas = document.getElementById("myCanvas");data = myCanvas.toDataURL('image/png');document.getElementById("result_output").value = "";kernel.execute("classify('" + data +"')",  { 'iopub' : {'output' : handle_output}}, {silent:false});}function myClear() {var myCanvas = document.getElementById("myCanvas");myCanvas.getContext("2d").clearRect(0, 0, myCanvas.width, myCanvas.height);}</script>"""
HTML(html+script)
# Out:
# <style type="text/css">canvas { border: 1px solid black; }</style><div id="board"><canvas id="myCanvas" width="100px" height="100px">Sorry, your browser doesn't support canvas technology.</canvas><p><button id="classify" onclick="classify()">Classify</button><button id="clear" onclick="myClear()">Clear</button>Result: <input type="text" id="result_output" size="5" value=""></p></div><script type="text/JavaScript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.2/jquery.min.js?ver=1.4.2"></script><script type="text/javascript">function init() {var myCanvas = document.getElementById("myCanvas");var curColor = $('#selectColor option:selected').val();if(myCanvas){var isDown = false;var ctx = myCanvas.getContext("2d");var canvasX, canvasY;ctx.lineWidth = 8;$(myCanvas).mousedown(function(e){isDown = true;ctx.beginPath();var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.moveTo(canvasX, canvasY);}).mousemove(function(e){if(isDown != false) {var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.lineTo(canvasX, canvasY);ctx.strokeStyle = curColor;ctx.stroke();}}).mouseup(function(e){isDown = false;ctx.closePath();});}$('#selectColor').change(function () {curColor = $('#selectColor option:selected').val();});}init();function handle_output(out) {document.getElementById("result_output").value = out.content.data["text/plain"];}function classify() {var kernel = IPython.notebook.kernel;var myCanvas = document.getElementById("myCanvas");data = myCanvas.toDataURL('image/png');document.getElementById("result_output").value = "";kernel.execute("classify('" + data +"')",  { 'iopub' : {'output' : handle_output}}, {silent:false});}function myClear() {var myCanvas = document.getElementById("myCanvas");myCanvas.getContext("2d").clearRect(0, 0, myCanvas.width, myCanvas.height);}</script>

# %% [markdown]
# ### Debugging
#
# DNNs can perform poorly for a lot of reasons, like learning rate too big/small, initialization too big/small, network structure not reasonable, etc. When this happens it's often helpful to print out the weights and intermediate outputs to understand what's going on. MXNet provides a monitor utility that does this:

# %%
def norm_stat(d):
    """The statistics you want to see.
    We compute the L2 norm here but you can change it to anything you like."""
    return mx.nd.norm(d)/np.sqrt(d.size)
mon = mx.mon.Monitor(
    100,                 # Print every 100 batches
    norm_stat,           # The statistics function defined above
    pattern='.*weight',  # A regular expression. Only arrays with name matching this pattern will be included.
    sort=True)           # Sort output by name
model = mx.model.FeedForward(ctx = mx.cpu(), symbol = mlp, num_epoch = 1,
                             learning_rate = 0.1, momentum = 0.9, wd = 0.00001)
model.fit(X=train_iter, eval_data=val_iter, monitor=mon,  # Set the monitor here
          batch_end_callback = mx.callback.Speedometer(100, 100))
# Out:
# /home/lpola/.virtualenvs/cv/lib/python2.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#   # This is added back by InteractiveShellApp.init_path()
# INFO:root:Start training with [cpu(0)]
# INFO:root:Batch:       1 fc1_backward_weight            0.000644166
# INFO:root:Batch:       1 fc1_weight                     0.0057854
# INFO:root:Batch:       1 fc2_backward_weight            0.00219758
# INFO:root:Batch:       1 fc2_weight                     0.00573691
# INFO:root:Batch:       1 fc3_backward_weight            0.00616249
# INFO:root:Batch:       1 fc3_weight                     0.00570547
# INFO:root:Epoch[0] Batch [100]	Speed: 7762.90 samples/sec	Train-accuracy=0.147400
# INFO:root:Batch:     101 fc1_backward_weight            0.136513
# INFO:root:Batch:     101 fc1_weight                     0.00796664
# INFO:root:Batch:     101 fc2_backward_weight            0.384423
# INFO:root:Batch:     101 fc2_weight                     0.0190929
# INFO:root:Batch:     101 fc3_backward_weight            2.82906
# INFO:root:Batch:     101 fc3_weight                     0.0734611
# INFO:root:Epoch[0] Batch [200]	Speed: 8906.77 samples/sec	Train-accuracy=0.693600
# INFO:root:Batch:     201 fc1_backward_weight            0.191167
# INFO:root:Batch:     201 fc1_weight                     0.0230887
# INFO:root:Batch:     201 fc2_backward_weight            0.445619
# INFO:root:Batch:     201 fc2_weight                     0.0488036
# INFO:root:Batch:     201 fc3_backward_weight            1.03559
# INFO:root:Batch:     201 fc3_weight                     0.223976
# INFO:root:Epoch[0] Batch [300]	Speed: 8346.19 samples/sec	Train-accuracy=0.892100
# INFO:root:Batch:     301 fc1_backward_weight            0.185537
# INFO:root:Batch:     301 fc1_weight                     0.0307468
# INFO:root:Batch:     301 fc2_backward_weight            0.305723
# INFO:root:Batch:     301 fc2_weight                     0.0609391
# INFO:root:Batch:     301 fc3_backward_weight            0.651367
# INFO:root:Batch:     301 fc3_weight                     0.245434
# INFO:root:Epoch[0] Batch [400]	Speed: 11172.27 samples/sec	Train-accuracy=0.925600
# INFO:root:Batch:     401 fc1_backward_weight            0.16532
# INFO:root:Batch:     401 fc1_weight                     0.0360402
# INFO:root:Batch:     401 fc2_backward_weight            0.30403
# INFO:root:Batch:     401 fc2_weight                     0.0692713
# INFO:root:Batch:     401 fc3_backward_weight            0.545315
# INFO:root:Batch:     401 fc3_weight                     0.256079
# INFO:root:Epoch[0] Batch [500]	Speed: 8987.88 samples/sec	Train-accuracy=0.937900
# INFO:root:Batch:     501 fc1_backward_weight            0.248233
# INFO:root:Batch:     501 fc1_weight                     0.0394965
# INFO:root:Batch:     501 fc2_backward_weight            0.502197
# INFO:root:Batch:     501 fc2_weight                     0.075249
# INFO:root:Batch:     501 fc3_backward_weight            1.04928
# INFO:root:Batch:     501 fc3_weight                     0.260208
# INFO:root:Epoch[0] Batch [600]	Speed: 6589.06 samples/sec	Train-accuracy=0.944400
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=7.239
# INFO:root:Epoch[0] Validation-accuracy=0.949400

# %% [markdown]
# ### Convolutional Neural Networks
#
# Note that the previous fully-connected layer simply reshapes the image into a vector during training. It ignores the spatial information that pixels are correlated on both horizontal and vertical dimensions. The convolutional layer aims to improve this drawback by using a more structural weight $W$. Instead of simply matrix-matrix multiplication, it uses 2-D convolution to obtain the output.
# <img src="https://thatindiandude.github.io/images/conv.png">
# We can also have multiple feature maps, each with their own weight matrices, to capture different features:
# <img src="https://thatindiandude.github.io/images/filters.png">
# Besides the convolutional layer, another major change of the convolutional neural network is the adding of pooling layers. A pooling layer reduce a $n\times m$ (often called kernal size) image patch into a single value to make the network less sensitive to the spatial location.
# <img src="https://thatindiandude.github.io/images/pooling.png">
# Then, we can use dropout before fully-linked layer to reduce the overfitting and increase robustness for NN.

# %%
#Create a CNN, you can design your own CNN   
def dmnistCNN():
    data = mx.symbol.Variable('data')
    # first conv layer
    conv1 = mx.sym.Convolution(data=data, kernel=(5,5), num_filter=20)
    tanh1 = mx.sym.Activation(data=conv1, act_type="tanh")
    pool1 = mx.sym.Pooling(data=tanh1, pool_type="max", kernel=(2,2), stride=(2,2))
    
    # second conv layer
    conv2 = mx.sym.Convolution(data=pool1, kernel=(5,5), num_filter=50)
    tanh2 = mx.sym.Activation(data=conv2, act_type="tanh")
    pool2 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2,2), stride=(2,2))
    
    # first fullc layer
    flatten = mx.sym.Flatten(data=pool2)
    flatten = mx.sym.Dropout(data=flatten, p=0.5)
    fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500)
    tanh3 = mx.sym.Activation(data=fc1, act_type="tanh")
    
    # third fullc
    fc2 = mx.sym.FullyConnected(data=tanh3, num_hidden=10)
    # softmax loss
    lenet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')
    return lenet 

lenet=dmnistCNN()
mx.viz.plot_network(symbol=lenet, shape=shape)

# %%
## Train the CNN 
model = mx.model.FeedForward(
    # ctx = mx.gpu(0),     # use GPU 0 for training, others are same as before
    symbol = lenet,       
    num_epoch = 10,     
    learning_rate = 0.1)
model.fit(
    X=train_iter,  
    eval_data=val_iter, 
    batch_end_callback = mx.callback.Speedometer(batch_size, 200)
) 
assert model.score(val_iter) > 0.98, "Low validation accuracy."
# Out:
# /home/lpola/.virtualenvs/cv/lib/python2.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 122.24 samples/sec	Train-accuracy=0.112900
# INFO:root:Epoch[0] Batch [400]	Speed: 123.96 samples/sec	Train-accuracy=0.110850
# INFO:root:Epoch[0] Batch [600]	Speed: 152.17 samples/sec	Train-accuracy=0.112750
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=456.845
# INFO:root:Epoch[0] Validation-accuracy=0.113500
# INFO:root:Epoch[1] Batch [200]	Speed: 156.72 samples/sec	Train-accuracy=0.432800
# INFO:root:Epoch[1] Batch [400]	Speed: 179.35 samples/sec	Train-accuracy=0.889650
# INFO:root:Epoch[1] Batch [600]	Speed: 135.62 samples/sec	Train-accuracy=0.930950
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=386.851
# INFO:root:Epoch[1] Validation-accuracy=0.944500
# INFO:root:Epoch[2] Batch [200]	Speed: 139.45 samples/sec	Train-accuracy=0.952900
# INFO:root:Epoch[2] Batch [400]	Speed: 141.21 samples/sec	Train-accuracy=0.961550
# INFO:root:Epoch[2] Batch [600]	Speed: 143.49 samples/sec	Train-accuracy=0.968750
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=424.892
# INFO:root:Epoch[2] Validation-accuracy=0.975000
# INFO:root:Epoch[3] Batch [200]	Speed: 144.28 samples/sec	Train-accuracy=0.973700
# INFO:root:Epoch[3] Batch [400]	Speed: 182.46 samples/sec	Train-accuracy=0.975050
# INFO:root:Epoch[3] Batch [600]	Speed: 159.90 samples/sec	Train-accuracy=0.978000
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=373.725
# INFO:root:Epoch[3] Validation-accuracy=0.981900
# INFO:root:Epoch[4] Batch [200]	Speed: 178.10 samples/sec	Train-accuracy=0.979900
# INFO:root:Epoch[4] Batch [400]	Speed: 179.64 samples/sec	Train-accuracy=0.981300
# INFO:root:Epoch[4] Batch [600]	Speed: 186.25 samples/sec	Train-accuracy=0.982850
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=331.271
# INFO:root:Epoch[4] Validation-accuracy=0.984700
# INFO:root:Epoch[5] Batch [200]	Speed: 158.64 samples/sec	Train-accuracy=0.983700
# INFO:root:Epoch[5] Batch [400]	Speed: 140.71 samples/sec	Train-accuracy=0.985100
# INFO:root:Epoch[5] Batch [600]	Speed: 150.59 samples/sec	Train-accuracy=0.986750
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=401.295
# INFO:root:Epoch[5] Validation-accuracy=0.986800
# INFO:root:Epoch[6] Batch [200]	Speed: 128.97 samples/sec	Train-accuracy=0.987350
# INFO:root:Epoch[6] Batch [400]	Speed: 138.28 samples/sec	Train-accuracy=0.987650
# INFO:root:Epoch[6] Batch [600]	Speed: 164.60 samples/sec	Train-accuracy=0.988700
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=421.523
# INFO:root:Epoch[6] Validation-accuracy=0.988000
# INFO:root:Epoch[7] Batch [200]	Speed: 105.99 samples/sec	Train-accuracy=0.989350
# INFO:root:Epoch[7] Batch [400]	Speed: 146.52 samples/sec	Train-accuracy=0.989350
# INFO:root:Epoch[7] Batch [600]	Speed: 157.55 samples/sec	Train-accuracy=0.989900
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=452.407
# INFO:root:Epoch[7] Validation-accuracy=0.988900
# INFO:root:Epoch[8] Batch [200]	Speed: 195.06 samples/sec	Train-accuracy=0.991000
# INFO:root:Epoch[8] Batch [400]	Speed: 203.21 samples/sec	Train-accuracy=0.991200
# INFO:root:Epoch[8] Batch [600]	Speed: 199.92 samples/sec	Train-accuracy=0.991050
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=301.246
# INFO:root:Epoch[8] Validation-accuracy=0.989500
# INFO:root:Epoch[9] Batch [200]	Speed: 209.14 samples/sec	Train-accuracy=0.992200
# INFO:root:Epoch[9] Batch [400]	Speed: 206.65 samples/sec	Train-accuracy=0.992400
# INFO:root:Epoch[9] Batch [600]	Speed: 205.75 samples/sec	Train-accuracy=0.992250
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=289.875
# INFO:root:Epoch[9] Validation-accuracy=0.989100

# %%
# Save the model for later load 
prefix = 'mnistmodel'
iteration = 10
model.save(prefix)
# model_loaded = mx.model.FeedForward.load(prefix, iteration)
# Out:
# INFO:root:Saved checkpoint to "mnistmodel-0001.params"
# /home/lpola/mxnet/python/mxnet/model.py:870: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#   **kwargs)
